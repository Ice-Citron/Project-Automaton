# %% [markdown]
# ### Training Run - 200 SFP Cases and 200+48 Cases

# %% [markdown]
#   Run it like this instead:
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   bash rangers_training/bash/run_act_sfp_single.sh \
#     --run-name sfp_clean_198 \
#     --repo-id rangers-intrinsic/aic-act-sfp-clean-198 \
#     --cases-csv rangers_data/outputs/fixed_scene_batches/sfp_200_04-20-02-53_sfp/cases.csv
#
#   If you want the second run after that, use:
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   bash rangers_training/bash/run_act_sfp_single.sh \
#     --run-name sfp_clean_198_plus_48 \
#     --repo-id rangers-intrinsic/aic-act-sfp-clean-198-plus-48 \
#     --cases-csv rangers_data/outputs/fixed_scene_batches/sfp_200_04-20-02-53_sfp/cases.csv \
#     --cases-csv rangers_data/outputs/fixed_scene_batches/sfp_50_04-19-17-22_sfp/cases.csv

# %% [markdown]
# ### Training Run [Apr 20 - 1:43 pm]

# %% [markdown]
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   AIC_ACT_TRAIN_STEPS=20000 \
#   AIC_ACT_TRAIN_BATCH_SIZE=8 \
#   AIC_ACT_TRAIN_NUM_WORKERS=10 \
#   AIC_ACT_TRAIN_DEVICE=cuda \
#   AIC_ACT_TRAIN_SAVE_FREQ=5000 \
#   AIC_ACT_TRAIN_LOG_FREQ=100 \
#   AIC_ACT_TRAIN_WANDB=true \
#   AIC_ACT_TRAIN_WANDB_PROJECT=aic-act-training \
#   bash rangers_training/bash/train_act_dataset.sh \
#     --run-name sfp_clean_198 \
#     --repo-id rangers-intrinsic/aic-act-sfp-clean-198 \
#     --dataset-root \
#     rangers_training/outputs/act_datasets/sfp_clean_198_2026-04-20_12-31-19 \
#     --private \
#     --publish
