# %% [markdown]
# ---

# %% [markdown]
#   cd ~/projects/Project-Automaton/References/aic
#   ~/.pixi/bin/pixi run python3 -m mujoco.viewer
#   --mjcf=aic_utils/aic_mujoco/mjcf/test_mounts_settle.xml
