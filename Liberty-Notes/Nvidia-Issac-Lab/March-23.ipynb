# %% [markdown]
# ---

# %% [markdown]
# ### Isaac Sim bootup
#
# ```bash
#   cd C:/IsaacLab/aic/aic_utils/aic_isaac/aic_isaaclab/scripts/rsl_rl/
#   C:/IsaacLab/_isaac_sim/python.bat train.py --task AIC-Task-v0 --headless --enable_cameras
#   --num_envs 16 --max_iterations 20
# ```
