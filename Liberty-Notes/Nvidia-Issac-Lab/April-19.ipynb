# %% [markdown]
# ### Teleop Code

# %% [markdown]
#   Terminal 1
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   export TASK_BOARD_X=0.3
#   export TASK_BOARD_Y=-0.1
#   export TASK_BOARD_Z=1.2
#   export TASK_BOARD_ROLL=0.0
#   export TASK_BOARD_PITCH=0.0
#   export TASK_BOARD_YAW=0.785
#
#   export SFP_MOUNT_RAIL_0_PRESENT=true
#   export SFP_MOUNT_RAIL_0_TRANSLATION=-0.08
#   export SC_MOUNT_RAIL_0_PRESENT=true
#   export SC_MOUNT_RAIL_0_TRANSLATION=-0.09
#   export NIC_CARD_MOUNT_0_PRESENT=true
#   export NIC_CARD_MOUNT_0_TRANSLATION=0.005
#   export SC_PORT_0_PRESENT=true
#   export SC_PORT_0_TRANSLATION=-0.04
#
#   export SPAWN_TASK_BOARD=true
#   export SPAWN_CABLE=true
#   export CABLE_TYPE=sfp_sc_cable
#   export ATTACH_CABLE_TO_GRIPPER=true
#   export GROUND_TRUTH=true
#   export START_AIC_ENGINE=false
#   export SHUTDOWN_ON_AIC_ENGINE_EXIT=false
#
#   bash rangers_teleop/bash/gazebo_practice_teleop.sh
#
#   Terminal 2
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#   unset CONDA_SUBDIR PIXI_PLATFORM PIXI_ENVIRONMENT_PLATFORMS CONDA_PREFIX CONDA_DEFAULT_ENV
#   pixi run --frozen ros2 service call /aic_controller/tare_force_torque_sensor std_srvs/srv/Trigger
#
#   Terminal 3
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#   unset CONDA_SUBDIR PIXI_PLATFORM PIXI_ENVIRONMENT_PLATFORMS CONDA_PREFIX CONDA_DEFAULT_ENV
#   bash rangers_teleop/bash/gazebo_cartesian_teleop.sh

# %% [markdown]
# ### CheatCode Demonstratioons for SC and SFP [2:30 am - 18 Apr]

# %% [markdown]
#  Cleanup first
#   Paste this in one terminal before starting anything else:
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   bash rangers-data/bash/stop_fixed_scene_cheatcode.sh
#
#   SC fixed-scene CheatCode
#
#   Terminal 1: Gazebo / scene
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   export DBX_CONTAINER_MANAGER=docker
#   export SPAWN_TASK_BOARD=true
#   export TASK_BOARD_X=0.3
#   export TASK_BOARD_Y=-0.1
#   export TASK_BOARD_Z=1.2
#   export TASK_BOARD_ROLL=0.0
#   export TASK_BOARD_PITCH=0.0
#   export TASK_BOARD_YAW=0.785
#
#   export SFP_MOUNT_RAIL_0_PRESENT=false
#   export SFP_MOUNT_RAIL_0_TRANSLATION=-0.08
#
#   export SC_MOUNT_RAIL_0_PRESENT=true
#   export SC_MOUNT_RAIL_0_TRANSLATION=-0.09
#
#   export NIC_CARD_MOUNT_0_PRESENT=false
#   export NIC_CARD_MOUNT_0_TRANSLATION=0.005
#
#   export SC_PORT_0_PRESENT=true
#   export SC_PORT_0_TRANSLATION=-0.04
#
#   export SPAWN_CABLE=true
#   export CABLE_TYPE=sfp_sc_cable_reversed
#   export ATTACH_CABLE_TO_GRIPPER=true
#
#   export GROUND_TRUTH=true
#   export START_AIC_ENGINE=false
#   export SHUTDOWN_ON_AIC_ENGINE_EXIT=false
#   export SKIP_MODEL_READY=true
#   export SKIP_READY_SIMULATOR=true
#
#   bash rangers_teleop/bash/gazebo_engine_teleop.sh
#
#   Terminal 2: CheatCode policy
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   unset CONDA_SUBDIR
#   unset PIXI_PLATFORM
#   unset PIXI_ENVIRONMENT_PLATFORMS
#   unset CONDA_PREFIX
#   unset CONDA_DEFAULT_ENV
#
#   bash rangers-data/bash/gazebo_cheatcode_policy.sh
#
#   Terminal 3: task dispatch
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   bash rangers-data/bash/run_fixed_scene_task.sh \
#     --task-id fixed_scene_sc \
#     --cable-type sfp_sc \
#     --cable-name cable_0 \
#     --plug-type sc \
#     --plug-name sc_tip \
#     --port-type sc \
#     --port-name sc_port_base \
#     --target-module-name sc_port_0 \
#     --time-limit 180
#
#   SFP fixed-scene CheatCode
#
#   Terminal 1: Gazebo / scene
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   export DBX_CONTAINER_MANAGER=docker
#   export SPAWN_TASK_BOARD=true
#   export TASK_BOARD_X=0.3
#   export TASK_BOARD_Y=-0.1
#   export TASK_BOARD_Z=1.2
#   export TASK_BOARD_ROLL=0.0
#   export TASK_BOARD_PITCH=0.0
#   export TASK_BOARD_YAW=0.785
#
#   export SFP_MOUNT_RAIL_0_PRESENT=true
#   export SFP_MOUNT_RAIL_0_TRANSLATION=-0.08
#
#   export SC_MOUNT_RAIL_0_PRESENT=false
#   export SC_MOUNT_RAIL_0_TRANSLATION=-0.09
#
#   export NIC_CARD_MOUNT_0_PRESENT=true[text](April-18.ipynb)
#   export NIC_CARD_MOUNT_0_TRANSLATION=0.005
#
#   export SC_PORT_0_PRESENT=false
#   export SC_PORT_0_TRANSLATION=-0.04
#
#   export SPAWN_CABLE=true
#   export CABLE_TYPE=sfp_sc_cable
#   export ATTACH_CABLE_TO_GRIPPER=true
#
#   export GROUND_TRUTH=true
#   export START_AIC_ENGINE=false
#   export SHUTDOWN_ON_AIC_ENGINE_EXIT=false
#   export SKIP_MODEL_READY=true
#   export SKIP_READY_SIMULATOR=true
#
#   bash rangers_teleop/bash/gazebo_engine_teleop.sh
#
#   Terminal 2: CheatCode policy
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
# [text](April-18.ipynb)
#   unset CONDA_SUBDIR
#   unset PIXI_PLATFORM
#   unset PIXI_ENVIRONMENT_PLATFORMS
#   unset CONDA_PREFIX
#   unset CONDA_DEFAULT_ENV
#
#   bash rangers-data/bash/gazebo_cheatcode_policy.sh
#
#   Terminal 3: task dispatch
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   bash rangers-data/bash/run_fixed_scene_task.sh \
#     --task-id fixed_scene_sfp \
#     --cable-type sfp_sc \
#     --cable-name cable_0 \
#     --plug-type sfp \
#     --plug-name sfp_tip \
#     --port-type sfp \
#     --port-name sfp_port_0 \
#     --target-module-name nic_card_mount_0 \
#     --time-limit 180

# %% [markdown]
# ### Intervention-Style Cheat Code TELEOP [18 Apr - 12:02 pm]

# %% [markdown]
#   Use this cleanup before starting a fresh session:
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   bash rangers_data/bash/stop_fixed_scene_cheatcode.sh
#
#   pkill -f cartesian_keyboard_teleop.py || true
#   pkill -f aic_ros_recorder_node || true
#   pkill -f run_fixed_scene_task.py || true
#   pkill -f "ros2 run aic_model aic_model" || true
#
# ---
#
#   Terminal 1
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#   bash rangers_teleop/bash/gazebo_scene_sc_intervention.sh
#
#   Terminal 2
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#   bash rangers_teleop/bash/gazebo_intervention_session.sh \
#     --task sc \
#     --session-name sc_intervention_001
#
#   Terminal 3
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#   unset CONDA_SUBDIR PIXI_PLATFORM PIXI_ENVIRONMENT_PLATFORMS CONDA_PREFIX CONDA_DEFAULT_ENV
#   bash rangers_teleop/bash/gazebo_cartesian_teleop_episode.sh
#
#
#
# ---
# So yes: with that exact Terminal 3 command, you are back on force-mode teleop.
#
# If you want to force it explicitly anyway, you can also do:
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#   unset CONDA_SUBDIR PIXI_PLATFORM PIXI_ENVIRONMENT_PLATFORMS CONDA_PREFIX CONDA_DEFAULT_ENV
#   TELEOP_COMMAND_MODE=force bash rangers_teleop/bash/gazebo_cartesian_teleop_episode.sh

# %% [markdown]
# ### Agent B - 50 SC teleop-cases

# %% [markdown]
# Generate 50 cases once:
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/\
#   aic-rangers-isaac-training
#
#   bash rangers_teleop/bash/generate_sc_manual_cases.sh \
#     --count 50 \
#     --batch-name sc_manual_batch_001
#
#   Terminal 1:
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/\
#   aic-rangers-isaac-training
#
#   bash rangers_teleop/bash/gazebo_scene_sc_case.sh \
#     --cases-csv \
#     rangers_teleop/outputs/manual_sc_cases/sc_manual_batch_001/cases.csv \
#     --case-name \
#     sc_manual_batch_001_001 \
#     --session-name \
#     sc_manual_batch_001_001
#
#   Terminal 2:
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/\
#   aic-rangers-isaac-training
#
#   unset CONDA_SUBDIR PIXI_PLATFORM PIXI_ENVIRONMENT_PLATFORMS \
#     CONDA_PREFIX CONDA_DEFAULT_ENV
#
#   pixi run --frozen ros2 service call \
#     /aic_controller/tare_force_torque_sensor \
#     std_srvs/srv/Trigger
#
#   bash rangers_teleop/bash/gazebo_record.sh \
#     --session-name sc_manual_batch_001_001
#
#   Terminal 3:
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/\
#   aic-rangers-isaac-training
#
#   unset CONDA_SUBDIR PIXI_PLATFORM PIXI_ENVIRONMENT_PLATFORMS \
#     CONDA_PREFIX CONDA_DEFAULT_ENV
#
#   bash rangers_teleop/bash/gazebo_cartesian_teleop.sh
#
#   Start the single trial:
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/\
#   aic-rangers-isaac-training
#
#   bash rangers_teleop/bash/gazebo_episode_start.sh
#
#   Stop the single trial:
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/\
#   aic-rangers-isaac-training
#
#   bash rangers_teleop/bash/gazebo_episode_stop.sh
#
#   Validate afterward:
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/\
#   aic-rangers-isaac-training
#
#   bash rangers_teleop/bash/validate_gazebo_session.sh \
#     sc_manual_batch_001_001
#
#   Success case:
#
#   - terminal 1 launches a randomized SC scene for the chosen case_name
#   - terminal 2 records into
#     rangers_teleop/outputs/gazebo_teleop/sc_manual_batch_001_001/
#   - terminal 3 teleops manually from scratch
#   - after stop, validate_gazebo_session.sh shows parquet + mp4 files
#   - the exact scene config for that recording exists at
#     rangers_teleop/outputs/gazebo_teleop/sc_manual_batch_001_001/scene_manifest.json

# %% [markdown]
# ### Agent A - 100 SFP cases

# %% [markdown]
#    - /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training/rangers_data/outputs/fixed_scene_batches/sfp_50_04-19-17-22_sfp/#
#
#
# 200 CASES ---
#
#   Cleanup
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   bash rangers_data/bash/stop_fixed_scene_cheatcode.sh
#
#   pkill -f cartesian_keyboard_teleop.py || true
#   pkill -f aic_ros_recorder_node || true
#   pkill -f run_fixed_scene_task.py || true
#   pkill -f "ros2 run aic_model aic_model" || true
#
#   Overnight 200-case SFP run
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   export RUN_SEED=42069420
#   export RUN_STAMP=$(date +%m-%d-%H-%M)
#
#   bash rangers_data/bash/generate_fixed_scene_batch.sh \
#     --mode sfp \
#     --count 200 \
#     --seed ${RUN_SEED} \
#     --scene-profile generalization \
#     --nic-count-profile qualification_mix \
#     --sfp-target-pool all \
#     --session-prefix sfp_200_${RUN_STAMP}_sfp

# %% [markdown]
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   bash rangers_teleop/bash/reset_gazebo_eval_stack.sh
#
#   SCRIPTED_SMOKE_BATCH_SC_COUNT=0 \
#   SCRIPTED_SMOKE_BATCH_SFP_COUNT=100 \
#   SCRIPTED_SMOKE_BATCH_PREFIX=sfp_100_$(date +%m-%d-%H-%M) \
#   SCRIPTED_SMOKE_EXPORT_PREVIEW=true \
#   bash rangers_data/bash/generate_scripted_smoke_batches.sh

# %% [markdown]
# ### 198 + 48 SFP Run [Agent A]

# %% [markdown]
#   For the 198 + 48 run, use explicit two-step commands, not the wrapper.
#
#   Build the merged ACT dataset:
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   bash rangers_training/bash/build_act_dataset_from_cases.sh \
#     --run-name sfp_clean_198_plus_48 \
#     --cases-csv \
#     rangers_data/outputs/fixed_scene_batches/sfp_200_04-20-02-53_sfp/cases.csv \
#     --cases-csv \
#     rangers_data/outputs/fixed_scene_batches/sfp_50_04-19-17-22_sfp/cases.csv \
#     --mix-seed 20260420
#
#
#
#
#   Then train on it:
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#
#   AIC_ACT_TRAIN_STEPS=220000 \
#   AIC_ACT_TRAIN_BATCH_SIZE=4 \
#   AIC_ACT_TRAIN_NUM_WORKERS=2 \
#   AIC_ACT_TRAIN_DEVICE=cuda \
#   AIC_ACT_TRAIN_SAVE_FREQ=10000 \
#   AIC_ACT_TRAIN_LOG_FREQ=100 \
#   AIC_ACT_TRAIN_WANDB=true \
#   AIC_ACT_TRAIN_WANDB_PROJECT=aic-act-training \
#   AIC_TRAIN_PREFETCH_FACTOR=1 \
#   bash rangers_training/bash/train_act_dataset.sh \
#     --run-name sfp_clean_198_plus_48 \
#     --repo-id rangers-intrinsic/aic-act-sfp-clean-198-plus-48 \
#     --dataset-root \
#     rangers_training/outputs/act_datasets/sfp_clean_198_plus_48_$(date +%Y-%m-%d_%H-%M-%S) \
#     --private \
#     --publish

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
verification of pushing onto Hugging Face:
Short answer: the generated cases are already in LeRobot format individually.

  For example, each case lives like this:

  - /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training/rangers_data/outputs/
    gazebo_data/sfp_50_04-19-17-22_sfp_050/parquet_root/experiment_1

  That experiment_1 root is the local LeRobot dataset for that one case.

  What was missing was the consolidated training dataset. I’m handling that now:

  - raw HF batch push is done:
    https://huggingface.co/datasets/rangers-intrinsic/sfp-50-04-19-17-22-preannotation
  - merged local LeRobot dataset currently being built:
    /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training/rangers_data/outputs/
    lerobot_datasets/sfp_50_04-19-17-22_success_only

  So no, you do not need to do the conversion yourself afterwards. The only thing still in flight is the
  merge from 48 successful per-case roots into one training root. The process is active and CPU-bound, not
  stalled. If you want, after it finishes I can either:

  - leave it as a local merged LeRobot dataset for training, or
  - publish that merged dataset to Hugging Face too.

• The generated runs are already in LeRobot format per case. Each case has its own local LeRobot root at a
  path like aic-rangers-isaac-training/rangers_data/outputs/gazebo_data/sfp_50_04-19-17-22_sfp_050/
  parquet_root/experiment_1, so you do not need to manually convert those one by one.

  What I’ve done is finish the raw batch HF upload and start the proper merge into one consolidated train
  ing dataset. The raw batch is here:
  https://huggingface.co/datasets/rangers-intrinsic/sfp-50-04-19-17-22-preannotation. The merged local Le
  Robot dataset is being built at aic-rangers-isaac-training/rangers_data/outputs/lerobot_datasets/sfp_50
  _04-19-17-22_success_only. I also fixed the merge script so it correctly recognizes your clean_success
  rows from cases.csv instead of incorrectly filtering them out.

  So the answer is: the per-case data is already LeRobot; the merged training dataset is the extra step,
  and I’m handling that now. After it finishes, I can either leave it local for training or publish the
  merged LeRobot dataset to Hugging Face as well.

# %% [markdown]
# Copied scoring.yaml to /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training/rangers_data/outputs/gazebo_data/sfp_100_04-19-23-11_sfp_065/parquet_root/experiment_1/scoring.yaml
# Running: /home/starforge-sf95/.pixi/bin/pixi run --frozen ros2 run aic_ros_recorder aic_ros_postprocess_scoring /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training/rangers_data/outputs/gazebo_data/sfp_100_04-19-23-11_sfp_065/parquet_root/experiment_1
# Annotated dataset at /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training/rangers_data/outputs/gazebo_data/sfp_100_04-19-23-11_sfp_065/parquet_root/experiment_1 using scores from /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training/rangers_data/outputs/gazebo_data/sfp_100_04-19-23-11_sfp_065/parquet_root/experiment_1/scoring.yaml
# Added columns: score_tier_1, score_tier_2, score_tier_3 to data parquet files and meta/episodes parquet files.
# Stopping policy (pid 2986928)
# Stopping engine (pid 2976075)
# Audit written to: /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training/rangers_data/outputs/fixed_scene_batches/sfp_100_04-19-23-11_sfp/audits/sfp_100_04-19-23-11_sfp_065
# Bucket counts:
#   - clean_success: 1
# Recommended primary use: good_candidate_for_imitation_training
# Exporting dataset preview videos to: /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training/rangers_data/outputs/fixed_scene_batches/sfp_100_04-19-23-11_sfp/previews/sfp_100_04-19-23-11_sfp_065
# [1/1] exporting episode 0 frames [0, 459)
#   wrote /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training/rangers_data/outputs/fixed_scene_batches/sfp_100_04-19-23-11_sfp/previews/sfp_100_04-19-23-11_sfp_065/experiment_1_episode_000.mp4
# Starting engine
#   pid: 2992091
#   log: /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training/rangers_data/outputs/fixed_scene_runs/sfp_100_04-19-23-11_sfp_066/logs/engine.log
