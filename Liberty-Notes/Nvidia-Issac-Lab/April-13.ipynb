# %% [markdown]
# ### Dataset Viewer
#
# ```bash
#   bash rangers_training/bash/peek_dataset.sh \
#     /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training/rangers_training/
#   outputs/act_datasets/experiment_8_three_camera_images \
#     --scale 1.0
# ```

# %% [markdown]
#   Terminal 1
#
#   export DBX_CONTAINER_MANAGER=docker
#
#   distrobox rm -r -f aic_eval
#   docker pull ghcr.io/intrinsic-dev/aic/aic_eval:latest
#   distrobox create -r --pull --nvidia --image ghcr.io/intrinsic-dev/aic/aic_eval:latest --name aic_eval
#   distrobox enter -r aic_eval -- /entrypoint.sh ground_truth:=false start_aic_engine:=true
#
#   Terminal 2: joint teleop
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#   unset CONDA_SUBDIR
#   pixi install --frozen
#   pixi run --frozen python3 aic_utils/aic_teleoperation/aic_teleoperation/joint_keyboard_teleop.py
#
#   Terminal 2: cartesian teleop
#
#   cd /home/starforge-sf95/Black-Projects/Project-Automaton/aic-rangers-isaac-training
#   unset CONDA_SUBDIR
#   pixi install --frozen
#   pixi run --frozen python3 aic_utils/aic_teleoperation/aic_teleoperation/cartesian_keyboard_teleop.py
