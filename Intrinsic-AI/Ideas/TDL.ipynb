# %% [markdown]
#   1. Today (Copy-out): You now understand the 10 key files. The architecture is: Engine sends Task → AicModel calls your insert_cable() → You read
#   Observations and send MotionUpdates → Scoring evaluates results.
#   2. Tomorrow (Isaac Sim): Get Isaac Sim running with the UR5e. Port the task board into USD format. Set up the ROS 2 bridge so the same
#   Observation/MotionUpdate topics flow through Isaac Sim instead of Gazebo.
#   3. This Week: Run CheatCode with ground_truth:=true to collect demonstration trajectories. Use these to train an ACT or diffusion policy via
#   LeRobot.
#   4. Next: Replace ground truth perception with a camera-based vision model (fine-tuned on sim images). This is where your Isaac Sim work pays off —
#   you can render thousands of training images with randomized board layouts.
